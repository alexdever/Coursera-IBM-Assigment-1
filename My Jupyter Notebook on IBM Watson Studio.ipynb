# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# ##### Alejandro Dever Ph.D.
# Computational Archaeologist, Data Scientist

# %% [markdown]
# *Data Science is a method to obtain better information, and make better decision.  Lift the fog noise off data.*

# %% [markdown]
# In cell 4 my code will as two questions, name and experience in months and return experience in years.

# %%
name = input ("Enter your name:")
experience_months = input("Enter your expeirence in months: ")
experience_years = int(experience_months)/12
print ("Your experience in years is:")
print (experience_years)

# %% [markdown]
# #### Things to watch in this section:
#
#
# -  A Table.
# -  A HTML link.
# -  A nice map.
#
# |Experience Mo | Experience in Yrs |
# | ------ | ------ |
# | 459 | 38 |
# | ------ | ------
#
# Next: Take a look at a project I worked in:
#
# <a href= "https://alejandrodever.wixsite.com/website-1/post/how-ai-is-changing-personal-data-tracking"> Alejandro Dever Forensics Project </a>
#
#
#  And: "An Archaeological Distributon Map of Tierradentro, Colombia"
# <img src="https://static.wixstatic.com/media/54dfa7_97aaf1f3fa144bb59288295b0589752f~mv2.png" alt = "An Archaeological Distributon Map of Tierradentro, Colombia" title="Late Period" />
